# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn import cross_validation, metrics
from sklearn.model_selection import GridSearchCV

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4
# Out:
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from lxml import etree
parser=etree.XMLParser(load_dtd= True)
tree = etree.parse("/Users/huzuoliang/Desktop/features.xml",parser)
root = tree.getroot()
names=[]
target_names=''
featrue_names=[]
oh={}
for f in root:
    f_type = f.tag
    f_name = f.get('name')
    names.append(f_name)
    ohrange = f.getchildren()[0]
    targetFlag = f.getchildren()[2]
    trainFlag = f.getchildren()[3]
    onFlag = f.getchildren()[4]
    
    if targetFlag.text == 'true':
        target_names = f_name
    if trainFlag.text == 'true':
        featrue_names.append(f_name)
        oh[f_name] = list(range(-1,int(ohrange.text)))

# %%
names.append('cal_dt')

# %%
data = pd.read_csv('/Users/huzuoliang/Desktop/train_set/ajk/1212headweek',sep='\t',names=names)

# %%
data = data[data['city_id'] == 14].reset_index(drop=True)

# %%
train = data[featrue_names]
label = data[target_names]

# %%
oh_cols = pd.DataFrame()
for k,v in oh.items():
    cols_name_oh = pd.get_dummies(v).rename(lambda x: k +'_'+ str(v[x])).T
    k_oh = cols_name_oh.loc[train[k]]
    k_oh.reset_index(inplace=True)
    # reset_index后会自动加一个index,以保存原始的列index
    # 避免settingwithcopyWarning
    k_oh = k_oh.drop('index', axis=1)
    oh_cols = pd.concat([oh_cols,k_oh], axis=1)

all_data = pd.concat([oh_cols,label],axis=1)

# %%
from sklearn.utils import shuffle  
all_data = shuffle(all_data) 
sz = all_data.shape
train = all_data.head(int(sz[0] * 0.8)) 
test = all_data.tail(int(sz[0] * 0.2))
train.shape,test.shape
# Out:
# ((314972, 394), (78743, 394))

# %% [markdown]
# ## Params Mining

# %%
def modelfit(alg, dtrain, dtest, predictors, target_names = 'label', useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(dtrain[predictors].values, label=dtrain[target_names].values)
        xgtest = xgb.DMatrix(dtest[predictors].values)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
                          metrics='auc', early_stopping_rounds=early_stopping_rounds)
        alg.set_params(n_estimators=cvresult.shape[0])

    # Fit the algorithm on the data
    alg.fit(dtrain[predictors], dtrain[target_names], eval_metric='auc')

    # Predict training set:
    dtrain_predictions = alg.predict(dtrain[predictors])
    dtrain_predprob = alg.predict_proba(dtrain[predictors])[:, 1]

    # Print model report:
    print("\nModel Report")
    print("Accuracy : %.4g" % metrics.accuracy_score(dtrain[target_names].values, dtrain_predictions))
    print("AUC Score (Train): %f" % metrics.roc_auc_score(dtrain[target_names], dtrain_predprob))
    print("Logloss Score (Train): %f" % metrics.log_loss(dtrain[target_names], dtrain_predprob))
    #     Predict on testing data:
    dtest_predictions = alg.predict(dtest[predictors])
    dtest['predprob'] = alg.predict_proba(dtest[predictors])[:, 1]
    print("Accuracy : %.4g" % metrics.accuracy_score(dtest[target_names].values, dtest_predictions))
    print('AUC Score (Test): %f' % metrics.roc_auc_score(dtest[target_names], dtest['predprob']))
    print('Logloss Score (Test): %f' % metrics.log_loss(dtest[target_names], dtest['predprob']))
#     plt.figure()
#     xgb.plot_importance(alg.get_booster())
#     plt.show()
    # print(alg.booster().get_score('weight'))
    plt.figure(figsize=(45,4))
    feat_imp = pd.Series(alg.get_booster().get_score()).sort_values(ascending=False)
    feat_imp.plot(kind='bar', title='Feature Importances')
    plt.ylabel('Feature Importance Score')
    print(dtest['predprob'])

# %%
predictors = [x for x in train.columns if x not in [target_names]]

# %% [markdown]
# ### default params

# %%
import time
t0 = time.clock() 
# 默认参数
xgb0 = XGBClassifier(
        objective='binary:logistic',
        nthread=4,
        seed= 27)
modelfit(xgb0, train, test, predictors, target_names,useTrainCV=True)

print("Xgboost time " + str(time.clock() - t0) + "ms")
# Out:
# Model Report
# Accuracy : 0.8202
# AUC Score (Train): 0.723380
# Logloss Score (Train): 0.429264
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy : 0.8205
# AUC Score (Test): 0.715952
# Logloss Score (Test): 0.430931
# Xgboost time 561.115756ms

# %% [markdown]
# ### trees 50

# %%
import time
t0 = time.clock() 
# 指定参数，cv
xgb1 = XGBClassifier(
        n_estimators=50,
        objective='binary:logistic',
        nthread=4,
        seed= 27)
modelfit(xgb1, train, test, predictors, target_names,useTrainCV=True)

print("Xgboost time " + str(time.clock() - t0) + "ms")
# Out:
# Model Report
# Accuracy : 0.8198
# AUC Score (Train): 0.684060
# Logloss Score (Train): 0.443652
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy : 0.82
# AUC Score (Test): 0.676160
# Logloss Score (Test): 0.444900
# Xgboost time 274.7016500000001ms

# %% [markdown]
# ## tree 30

# %%
import time
t0 = time.clock() 
# 指定参数，cv
xgb1 = XGBClassifier(
        n_estimators=30,
        objective='binary:logistic',
        nthread=4,
        seed= 27)
modelfit(xgb1, train, test, predictors, target_names,useTrainCV=True)

print("Xgboost time " + str(time.clock() - t0) + "ms")
# Out:
# Model Report
# Accuracy : 0.8198
# AUC Score (Train): 0.650481
# Logloss Score (Train): 0.452635
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy : 0.82
# AUC Score (Test): 0.639662
# Logloss Score (Test): 0.454133
# Xgboost time 184.085195ms

# %%
t0 = time.clock() 
param_test1 = {
 'max_depth':list(range(3,10,2)),
 'min_child_weight':list(range(1,6,2))
}
gsearch1 = GridSearchCV(estimator = XGBClassifier(learning_rate =0.1, n_estimators=50,max_depth=5,
 min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27), 
 param_grid = param_test1, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch1.fit(train[predictors],train[target_names])
print("Xgboost time " + str(time.clock() - t0) + "s")
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# Xgboost time 155.28395799999998s
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.68519, std: 0.00285, params: {'max_depth': 3, 'min_child_weight': 1},
#   mean: 0.68589, std: 0.00247, params: {'max_depth': 3, 'min_child_weight': 3},
#   mean: 0.68557, std: 0.00426, params: {'max_depth': 3, 'min_child_weight': 5},
#   mean: 0.72198, std: 0.00306, params: {'max_depth': 5, 'min_child_weight': 1},
#   mean: 0.72217, std: 0.00181, params: {'max_depth': 5, 'min_child_weight': 3},
#   mean: 0.72313, std: 0.00277, params: {'max_depth': 5, 'min_child_weight': 5},
#   mean: 0.73729, std: 0.00243, params: {'max_depth': 7, 'min_child_weight': 1},
#   mean: 0.73700, std: 0.00236, params: {'max_depth': 7, 'min_child_weight': 3},
#   mean: 0.73641, std: 0.00215, params: {'max_depth': 7, 'min_child_weight': 5},
#   mean: 0.74334, std: 0.00401, params: {'max_depth': 9, 'min_child_weight': 1},
#   mean: 0.74363, std: 0.00259, params: {'max_depth': 9, 'min_child_weight': 3},
#   mean: 0.74424, std: 0.00304, params: {'max_depth': 9, 'min_child_weight': 5}],
#  {'max_depth': 9, 'min_child_weight': 5},
#  0.74424455516920562)

# %%
param_test2 = {
    'max_depth':[6,8,9],
    'min_child_weight':[1,4,6]
}
gsearch2 = GridSearchCV(estimator = XGBClassifier( learning_rate=0.1, n_estimators=50, max_depth=9,
                                        min_child_weight=5, gamma=0, subsample=0.8, colsample_bytree=0.8,
                                        objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
                       param_grid = param_test2, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch2.fit(train[predictors],train[target_names])
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=9, min_child_weight=5, missing=None, n_estimators=50,
#        n_jobs=1, nthread=4, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=27, silent=True,
#        subsample=0.8),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'max_depth': [6, 8, 9], 'min_child_weight': [1, 4, 6]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=0)

# %%
gsearch2.grid_scores_, gsearch2.best_params_, gsearch2.best_score_
# Out:
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.73189, std: 0.00152, params: {'max_depth': 6, 'min_child_weight': 1},
#   mean: 0.73066, std: 0.00195, params: {'max_depth': 6, 'min_child_weight': 4},
#   mean: 0.73291, std: 0.00267, params: {'max_depth': 6, 'min_child_weight': 6},
#   mean: 0.74043, std: 0.00274, params: {'max_depth': 8, 'min_child_weight': 1},
#   mean: 0.74123, std: 0.00228, params: {'max_depth': 8, 'min_child_weight': 4},
#   mean: 0.74130, std: 0.00228, params: {'max_depth': 8, 'min_child_weight': 6},
#   mean: 0.74334, std: 0.00401, params: {'max_depth': 9, 'min_child_weight': 1},
#   mean: 0.74386, std: 0.00227, params: {'max_depth': 9, 'min_child_weight': 4},
#   mean: 0.74450, std: 0.00270, params: {'max_depth': 9, 'min_child_weight': 6}],
#  {'max_depth': 9, 'min_child_weight': 6},
#  0.74449806508168126)

# %%
param_test2b = {
 'min_child_weight':[6,8,10,12]
}
gsearch2b = GridSearchCV(estimator = XGBClassifier( learning_rate=0.1, n_estimators=50, max_depth=9,
 min_child_weight=6, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test2b, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch2b.fit(train[predictors],train[target_names])
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=9, min_child_weight=6, missing=None, n_estimators=50,
#        n_jobs=1, nthread=4, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=27, silent=True,
#        subsample=0.8),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'min_child_weight': [6, 8, 10, 12]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=0)

# %%
gsearch2b.grid_scores_, gsearch2b.best_params_, gsearch2b.best_score_
# Out:
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.74450, std: 0.00270, params: {'min_child_weight': 6},
#   mean: 0.74386, std: 0.00286, params: {'min_child_weight': 8},
#   mean: 0.74474, std: 0.00362, params: {'min_child_weight': 10},
#   mean: 0.74455, std: 0.00218, params: {'min_child_weight': 12}],
#  {'min_child_weight': 10},
#  0.7447356273588347)

# %%
modelfit(gsearch2.best_estimator_, train,test, predictors,useTrainCV=False)
# Out:
# Model Report
# Accuracy : 0.8285
# AUC Score (Train): 0.795417
# Logloss Score (Train): 0.394090
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy : 0.8248
# AUC Score (Test): 0.745230
# Logloss Score (Test): 0.414425

# %%
param_test3 = {
 'gamma':[i/10.0 for i in range(0,5)]
}
gsearch3 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=50, max_depth=9,
 min_child_weight=10, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test3, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch3.fit(train[predictors],train[target_names])
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=9, min_child_weight=10, missing=None, n_estimators=50,
#        n_jobs=1, nthread=4, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=27, silent=True,
#        subsample=0.8),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'gamma': [0.0, 0.1, 0.2, 0.3, 0.4]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=0)

# %%
gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_
# Out:
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.74474, std: 0.00362, params: {'gamma': 0.0},
#   mean: 0.74481, std: 0.00292, params: {'gamma': 0.1},
#   mean: 0.74480, std: 0.00315, params: {'gamma': 0.2},
#   mean: 0.74466, std: 0.00254, params: {'gamma': 0.3},
#   mean: 0.74453, std: 0.00237, params: {'gamma': 0.4}],
#  {'gamma': 0.1},
#  0.74481253648008183)

# %%
param_test5 = {
 'subsample':[i/100.0 for i in range(75,90,5)],
 'colsample_bytree':[i/100.0 for i in range(75,90,5)]
}
gsearch5 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=50, max_depth=9,
 min_child_weight=10, gamma=0.1, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test5, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch5.fit(train[predictors],train[target_names])
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0.1, learning_rate=0.1,
#        max_delta_step=0, max_depth=9, min_child_weight=10, missing=None,
#        n_estimators=50, n_jobs=1, nthread=4, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=27, silent=True, subsample=0.8),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'subsample': [0.75, 0.8, 0.85], 'colsample_bytree': [0.75, 0.8, 0.85]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=0)

# %%
gsearch5.grid_scores_, gsearch5.best_params_, gsearch5.best_score_
# Out:
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.74448, std: 0.00264, params: {'colsample_bytree': 0.75, 'subsample': 0.75},
#   mean: 0.74399, std: 0.00302, params: {'colsample_bytree': 0.75, 'subsample': 0.8},
#   mean: 0.74409, std: 0.00286, params: {'colsample_bytree': 0.75, 'subsample': 0.85},
#   mean: 0.74480, std: 0.00265, params: {'colsample_bytree': 0.8, 'subsample': 0.75},
#   mean: 0.74481, std: 0.00292, params: {'colsample_bytree': 0.8, 'subsample': 0.8},
#   mean: 0.74423, std: 0.00357, params: {'colsample_bytree': 0.8, 'subsample': 0.85},
#   mean: 0.74471, std: 0.00311, params: {'colsample_bytree': 0.85, 'subsample': 0.75},
#   mean: 0.74412, std: 0.00210, params: {'colsample_bytree': 0.85, 'subsample': 0.8},
#   mean: 0.74501, std: 0.00237, params: {'colsample_bytree': 0.85, 'subsample': 0.85}],
#  {'colsample_bytree': 0.85, 'subsample': 0.85},
#  0.74501223105202485)

# %%
param_test7 = {
 'reg_alpha':[0, 0.001, 0.0025, 0.005, 0.01, 0.05]
}
gsearch7 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=50, max_depth=9,
 min_child_weight=10, gamma=0.1, subsample=0.85, colsample_bytree=0.85,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test7, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch7.fit(train[predictors],train[target_names])
gsearch7.grid_scores_, gsearch7.best_params_, gsearch7.best_score_
# Out:
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.74501, std: 0.00237, params: {'reg_alpha': 0},
#   mean: 0.74473, std: 0.00305, params: {'reg_alpha': 0.001},
#   mean: 0.74480, std: 0.00223, params: {'reg_alpha': 0.0025},
#   mean: 0.74478, std: 0.00273, params: {'reg_alpha': 0.005},
#   mean: 0.74447, std: 0.00302, params: {'reg_alpha': 0.01},
#   mean: 0.74374, std: 0.00296, params: {'reg_alpha': 0.05}],
#  {'reg_alpha': 0},
#  0.74501223105202485)

# %%
param_test8 = {
 'reg_lambda':[0, 0.001, 0.0025, 0.005, 0.01, 0.05]
}
gsearch8 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=50, max_depth=9,
 min_child_weight=10, gamma=0.1, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test8, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch8.fit(train[predictors],train[target_names])
gsearch8.grid_scores_, gsearch7.best_params_, gsearch7.best_score_
# Out:
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.74434, std: 0.00241, params: {'reg_lambda': 0},
#   mean: 0.74513, std: 0.00342, params: {'reg_lambda': 0.001},
#   mean: 0.74480, std: 0.00334, params: {'reg_lambda': 0.0025},
#   mean: 0.74487, std: 0.00343, params: {'reg_lambda': 0.005},
#   mean: 0.74492, std: 0.00276, params: {'reg_lambda': 0.01},
#   mean: 0.74497, std: 0.00291, params: {'reg_lambda': 0.05}],
#  {'reg_alpha': 0},
#  0.74501223105202485)

# %%
modelfit(gsearch8.best_estimator_, train,test, predictors,useTrainCV=True)
# Out:
# Model Report
# Accuracy : 0.8277
# AUC Score (Train): 0.790282
# Logloss Score (Train): 0.396255
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy : 0.8238
# AUC Score (Test): 0.742946
# Logloss Score (Test): 0.415396

# %%
gsearch8.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0.1, learning_rate=0.1,
#        max_delta_step=0, max_depth=9, min_child_weight=10, missing=None,
#        n_estimators=50, n_jobs=1, nthread=4, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=0.001, scale_pos_weight=1,
#        seed=27, silent=True, subsample=0.8)

# %%
spw =(len(label)-sum(label)) / sum(label)
spw
# Out:
# 4.5511026615969579

# %%
PARAMS = {'learning_rate': 0.06,
          'n_estimators': 300,
          'max_depth': 9,
          'min_child_weight': 10,
          'gamma': 0.1,
          'reg_alpha': 0,
          'subsample': 0.85,
          'colsample_bytree': 0.85,
          'objective': 'binary:logistic',
          'nthread': 4,
          'seed': 27,
          'scale_pos_weight': 4.55}

# %%
import time
t0 = time.clock() 
# 指定参数，cv
xgb7 = XGBClassifier(**PARAMS)
modelfit(xgb7, train, test, predictors, target_names,useTrainCV=False)

print("Xgboost time " + str(time.clock() - t0) + "ms")
# Out:
# Model Report
# Accuracy : 0.768
# AUC Score (Train): 0.882243
# Logloss Score (Train): 0.470640
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy : 0.7057
# AUC Score (Test): 0.758597
# Logloss Score (Test): 0.540691
# Xgboost time 869.4579859999994ms

# %% [markdown]
# ## more data

# %%
spw =(len(label)-sum(label)) / sum(label)
train.shape,test.shape
# Out:
# ((171044, 399), (42761, 400))

# %%
PARAMS = {'learning_rate': 0.06,
          'n_estimators': 300,
          'max_depth': 9,
          'min_child_weight': 10,
          'gamma': 0.1,
          'reg_alpha': 0,
          'subsample': 0.85,
          'colsample_bytree': 0.85,
          'objective': 'binary:logistic',
          'nthread': 4,
          'seed': 27,
          'scale_pos_weight': 4.55}

# %%
import time
t0 = time.clock() 
# 指定参数，cv
xgb7 = XGBClassifier(**PARAMS)
modelfit(xgb7, train, test, predictors, target_names,useTrainCV=False)

print("Xgboost time " + str(time.clock() - t0) + "ms")
# Out:
# Model Report
# Accuracy : 0.7525
# AUC Score (Train): 0.863300
# Logloss Score (Train): 0.488899
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy : 0.7022
# AUC Score (Test): 0.755642
# Logloss Score (Test): 0.545282
# Xgboost time 1302.5079320000004ms

# %%
PARAMS = {'learning_rate': 0.1,
          'n_estimators': 100,
          'max_depth': 9,
          'min_child_weight': 10,
          'gamma': 0.1,
          'reg_alpha': 0,
          'subsample': 0.85,
          'colsample_bytree': 0.85,
          'objective': 'binary:logistic',
          'nthread': 4,
          'seed': 27,
          'scale_pos_weight': 4.55}

import time
t0 = time.clock() 
# 指定参数，cv
xgb7 = XGBClassifier(**PARAMS)
modelfit(xgb7, train, test, predictors, target_names,useTrainCV=False)

print("Xgboost time " + str(time.clock() - t0) + "ms")
# Out:
# Model Report
# Accuracy : 0.714
# AUC Score (Train): 0.825918
# Logloss Score (Train): 0.530580
# /Users/huzuoliang/app/Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Accuracy : 0.6808
# AUC Score (Test): 0.753333
# Logloss Score (Test): 0.563672
# Xgboost time 426.0350209999997ms

# %%
PARAMS = {'learning_rate': 0.06,
          'n_estimators': 300,
          'max_depth': 9,
          'min_child_weight': 10,
          'gamma': 0.1,
          'reg_alpha': 0,
          'subsample': 0.85,
          'colsample_bytree': 0.85,
          'objective': 'binary:logistic',
          'nthread': 4,
          'seed': 27,
          'scale_pos_weight': 1}

import time
t0 = time.clock() 
# 指定参数，cv
xgb7 = XGBClassifier(**PARAMS)
modelfit(xgb7, train, test, predictors, target_names,useTrainCV=False)

print("Xgboost time " + str(time.clock() - t0) + "ms")

# %%
bst = xgb.Booster({'nthread': 1})  # init model
bst.load_model('/Users/huzuoliang/2017-12-11xgb.model.local')  # load data
alg=bst
print(bst)
# Out:
# <xgboost.core.Booster object at 0x111b6ab38>

# %%
atest = np.ones((1,393))

# %%
atest.shape,type(atest),test[predictors].shape,type(test)
# Out:
# ((1, 393), numpy.ndarray, (66894, 393), pandas.core.frame.DataFrame)

# %%
dtest = xgb.DMatrix(atest)
ypred = bst.predict(dtest)

# %%
ypred
# Out:
# array([ 0.42898309], dtype=float32)

# %%
test.columns
# Out:
# Index(['hour_expo_oh_-1', 'hour_expo_oh_0', 'hour_expo_oh_1', 'hour_expo_oh_2',
#        'hour_expo_oh_3', 'hour_expo_oh_4', 'hour_expo_oh_5',
#        'minute_expo_oh_-1', 'minute_expo_oh_0', 'minute_expo_oh_1',
#        ...
#        'hall_num_like_oh_-1', 'hall_num_like_oh_0', 'hall_num_like_oh_1',
#        'hall_num_like_oh_2', 'hall_num_like_oh_3', 'hall_num_like_oh_4',
#        'rent_type_like_oh_-1', 'rent_type_like_oh_0', 'rent_type_like_oh_1',
#        'label'],
#       dtype='object', length=394)
